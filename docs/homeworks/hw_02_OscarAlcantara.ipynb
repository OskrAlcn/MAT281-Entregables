# %% [markdown]
# <a href="https://colab.research.google.com/github/OskrAlcn/MAT281-Entregables/blob/main/docs/homeworks/hw_02_OscarAlcantara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281/blob/main/docs/homeworks/hw_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Tarea N°02

# %% [markdown]
# ## Objetivos de la Tarea
#
# El propósito de esta tarea es aplicar técnicas de **Machine Learning** con Python a dos contextos distintos:
# 1) el análisis del impacto del COVID-19 en el aprendizaje digital (LearnPlatform),
# 2) la predicción de supervivencia en el Titanic.
#
# ### Objetivos específicos:
#
# 1. **Preparar los datos**: integrar, limpiar y transformar los datasets para que puedan ser utilizados en modelos de aprendizaje automático.
#
# 2. **Explorar patrones relevantes**: analizar variables, detectar relaciones y seleccionar características útiles para el modelado.
#
# 3. **Construir modelos de ML**: implementar modelos supervisados (regresión, clasificación) utilizando librerías como `scikit-learn`.
#
# 4. **Evaluar desempeño**: comparar métricas como accuracy, precision, recall, F1-score y AUC para seleccionar los mejores enfoques.
#
# 5. **Generar conclusiones**: interpretar los resultados obtenidos y reflexionar sobre su impacto en la equidad educativa (LearnPlatform) y en la predicción de supervivencia (Titanic).

# %% [markdown]
# ## Instrucciones
#
# 1. Completa tus datos personales en la celda correspondiente:
#
#    * **Nombre**: Oscar Alcántara
#    * **Rol USM**: 202230555-k
#
# 2. Este archivo debe ser actualizado con tus respuestas y luego **subido a tu repositorio personal del curso**. Asegúrate de incluir todos los archivos necesarios para su ejecución (datos, imágenes, scripts, etc.).
#
# 3. La evaluación de la tarea considerará los siguientes aspectos:
#
#    * Desarrollo correcto de las soluciones solicitadas.
#    * Claridad, legibilidad y calidad del código.
#    * Reproducibilidad: al ejecutar `Kernel → Restart Kernel and Run All Cells`, el notebook debe correr sin errores.

# %% [markdown]
# ## I.- LearnPlatform
#
# <img src="https://images.squarespace-cdn.com/content/v1/5cb36dc993a63270cfacbc2b/338586d4-5b1e-4b48-b2b2-408b8dd0f1a3/LearnPlatform+logo.png" width = "400" align="center"/>

# %% [markdown]
# ### Introducción
#
# Nelson Mandela creía que la educación era el arma más poderosa para cambiar el mundo. Pero no todos los estudiantes tienen las mismas oportunidades de aprender. Es necesario promulgar políticas y planes efectivos para que la educación sea más equitativa, y tal vez su innovador análisis de datos ayude a revelar la solución.
#
# La investigación actual muestra que los resultados educativos están lejos de ser equitativos. El desequilibrio se vio agravado por la pandemia de COVID-19. Existe una necesidad urgente de comprender y medir mejor el alcance y el impacto de la pandemia en estas inequidades.
#
# La empresa de tecnología educativa LearnPlatform se fundó en 2014 con la misión de ampliar el acceso equitativo a la tecnología educativa para todos los estudiantes y profesores. Los distritos y estados utilizan el sistema integral de efectividad de la tecnología educativa de LearnPlatform para mejorar continuamente la seguridad, la equidad y la efectividad de su tecnología educativa. LearnPlatform lo hace generando una base de evidencia de lo que está funcionando y promulgándola en beneficio de los estudiantes, los profesores y los presupuestos.
#
# En esta competencia de análisis, trabajará para descubrir tendencias en el aprendizaje digital. Logre esto con un análisis de datos sobre cómo el compromiso con el aprendizaje digital se relaciona con factores como la demografía del distrito, el acceso a la banda ancha y las políticas y eventos a nivel estatal / nacional. Luego, envíe un notebook de Kaggle para proponer su mejor solución a estas desigualdades educativas.
#
# Sus presentaciones informarán las políticas y prácticas que cierran la brecha digital. Con una mejor comprensión de las tendencias de aprendizaje digital, puede ayudar a revertir la pérdida de aprendizaje a largo plazo entre los más vulnerables de Estados Unidos, haciendo que la educación sea más equitativa.
#
# ### Planteamiento del problema
# La pandemia COVID-19 ha interrumpido el aprendizaje de más de 56 millones de estudiantes en los Estados Unidos. En la primavera de 2020, la mayoría de los gobiernos estatales y locales de los EE. UU. Cerraron las instituciones educativas para detener la propagación del virus. En respuesta, las escuelas y los maestros han intentado llegar a los estudiantes de forma remota a través de herramientas de aprendizaje a distancia y plataformas digitales. Hasta el día de hoy, las preocupaciones sobre la exacerbación de la brecha digital y la pérdida de aprendizaje a largo plazo entre los estudiantes más vulnerables de Estados Unidos continúan creciendo.
#
# ### Desafío
# Los estudiantes deben explorar (1) el estado del aprendizaje digital en 2020 y (2) cómo la participación del aprendizaje digital se relaciona con factores como la demografía del distrito, el acceso a banda ancha y las políticas y eventos a nivel estatal/nacional.
#
# Le recomendamos que oriente el análisis con preguntas relacionadas con los temas descritos anteriormente (en negrita). A continuación se muestran algunos ejemplos de preguntas que se relacionan con el planteamiento de nuestro problema:
#
# * ¿Cuál es el panorama de la conectividad y el compromiso digitales en 2020?
# * ¿Cuál es el efecto de la pandemia de COVID-19 en el aprendizaje en línea y a distancia, y cómo podría evolucionar también en el futuro?
# * ¿Cómo cambia la participación de los estudiantes con los diferentes tipos de tecnología educativa durante el transcurso de la pandemia?
# * ¿Cómo se relaciona la participación de los estudiantes con las plataformas de aprendizaje en línea con las diferentes geografías? ¿Contexto demográfico (por ejemplo, raza/etnia, ESL, discapacidad de aprendizaje)? Contexto de aprendizaje? ¿Estatus socioeconómico?
# * ¿Se correlacionan ciertas intervenciones, prácticas o políticas estatales (por ejemplo, estímulo, reapertura, moratoria de desalojo) con el aumento o la disminución de la participación en línea?
#
# ### Evaluación
#
#
# #### Claridad
#
# * ¿El autor presentó un hilo claro de preguntas o temas que motivaron su análisis?
# * ¿El autor documentó por qué/cómo se eligió y utilizó un conjunto de métodos para su análisis?
# * ¿Está documentado el notebook de una manera que sea fácilmente reproducible (p. Ej., Código, fuentes de datos adicionales, citas)?
# * ¿El notebook contiene visualizaciones de datos claras que ayuden a comunicar de manera eficaz los hallazgos del autor tanto a expertos como a no expertos?
#
# #### Precisión
#
# * ¿El autor procesó los datos (por ejemplo, fusionando) y/o fuentes de datos adicionales con precisión?
# * ¿La metodología utilizada en el análisis es apropiada y razonable?
# * ¿Son razonables y convincentes las interpretaciones basadas en el análisis y la visualización?
#
# #### Creatividad
#
# * ¿El notebook ayuda al lector a aprender algo nuevo o lo desafía a pensar de una manera nueva?
# * ¿El notebook aprovecha métodos novedosos y/o visualizaciones que ayudan a revelar información a partir de datos y/o comunicar hallazgos?
# * ¿El autor utilizó fuentes de datos públicas adicionales en su análisis?

# %% [markdown]
# ### Hints
#
# * Esto corresponde a un desafio de Kaggle ([link](https://www.kaggle.com/c/learnplatform-covid19-impact-on-digital-learning/overview/description)).
# *  La información respecto a los datos, lo pueden encontrar en el siguiente [link](https://www.kaggle.com/c/learnplatform-covid19-impact-on-digital-learning/data).
# * A modo de inspiración, pueden ocupar algunos gráficos de otros participantes del desafío ([link](https://www.kaggle.com/c/learnplatform-covid19-impact-on-digital-learning/code)).

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import ticker
import os
from os import listdir
from os.path import isfile, join

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Lectura de los datos

path1 = '/content/drive/MyDrive/data_hw2/learnplatform-covid19-impact-on-digital-learning/engagement_data/'
path2 = '/content/drive/MyDrive/data_hw2/learnplatform-covid19-impact-on-digital-learning/'

engagement_files = [path1 + f for f in listdir(path1)]
districts = pd.read_csv(path2 + 'districts_info.csv')
products = pd.read_csv(path2 + 'products_info.csv')

engagement_data = pd.DataFrame()
for file_path in engagement_files:
    df = pd.read_csv(file_path)
    df['id'] = int(file_path[-8:-4]) #Para obtener el id del distrito
    engagement_data = pd.concat([engagement_data, df], ignore_index=True)



#Extraído de https://www.kaggle.com/code/assurivyshnavi/digital-learning
mapping_1 = {
    '[0, 0.2[': '0%-20%',
    '[0.2, 0.4[': '20%-40%',
    '[0.4, 0.6[': '40%-60%',
    '[0.6, 0.8[': '60%-80%',
    '[0.8, 1[': '80%-100%'}

mapping_2 = {
    '[4000, 6000[': '4000-6000',
    '[6000, 8000[': '6000-8000',
    '[8000, 10000[': '8000-10000',
    '[10000, 12000[': '10000-12000',
    '[12000, 14000[': '12000-14000',
    '[14000, 16000[': '14000-16000',
    '[16000, 18000[': '16000-18000',
    '[18000, 20000[': '18000-20000',
    '[20000, 22000[': '20000-22000',
    '[22000, 24000[': '22000-24000',
    '[32000, 34000[': '32000-34000'}

mapping_3 = {
    '[0.18, 1[': '18%-100%',
    '[1, 2[': '100%-200%'
}

districts['pct_black/hispanic'] = districts['pct_black/hispanic'].map(mapping_1)
districts['pct_free/reduced'] = districts['pct_free/reduced'].map(mapping_1)
districts['county_connections_ratio'] = districts['county_connections_ratio'].map(mapping_3)
districts['pp_total_raw'] = districts['pp_total_raw'].map(mapping_2)

products[['Category', 'Subcategory']] = products['Primary Essential Function'].str.split('-', n=1, expand=True,)
products = products.drop('Primary Essential Function', axis=1)



districts.head()
# Out:
#    district_id     state  locale pct_black/hispanic pct_free/reduced  \
# 0         8815  Illinois  Suburb             0%-20%           0%-20%
# 1         2685       NaN     NaN                NaN              NaN
# 2         4921      Utah  Suburb             0%-20%          20%-40%
# 3         3188       NaN     NaN                NaN              NaN
# 4         2238       NaN     NaN                NaN              NaN
#
#   county_connections_ratio pp_total_raw
# 0                 18%-100%  14000-16000
# 1                      NaN          NaN
# 2                 18%-100%    6000-8000
# 3                      NaN          NaN
# 4                      NaN          NaN

# %%
districts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   district_id               233 non-null    int64
#  1   state                     176 non-null    object
#  2   locale                    176 non-null    object
#  3   pct_black/hispanic        176 non-null    object
#  4   pct_free/reduced          148 non-null    object
#  5   county_connections_ratio  162 non-null    object
#  6   pp_total_raw              118 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 12.9+ KB

# %%
districts.describe(include = 'all')
# Out:
#         district_id        state  locale pct_black/hispanic pct_free/reduced  \
# count    233.000000          176     176                176              148
# unique          NaN           23       4                  5                5
# top             NaN  Connecticut  Suburb             0%-20%          20%-40%
# freq            NaN           30     104                116               48
# mean    5219.776824          NaN     NaN                NaN              NaN
# std     2595.751581          NaN     NaN                NaN              NaN
# min     1000.000000          NaN     NaN                NaN              NaN
# 25%     2991.000000          NaN     NaN                NaN              NaN
# 50%     4937.000000          NaN     NaN                NaN              NaN
# 75%     7660.000000          NaN     NaN                NaN              NaN
# max     9927.000000          NaN     NaN                NaN              NaN
#
#        county_connections_ratio pp_total_raw
# ...

# %%
for col in districts.columns:
  print(f'N° valores distintos en {col}: {districts[col].nunique()}')
# Out:
# N° valores distintos en district_id: 233
# N° valores distintos en state: 23
# N° valores distintos en locale: 4
# N° valores distintos en pct_black/hispanic: 5
# N° valores distintos en pct_free/reduced: 5
# N° valores distintos en county_connections_ratio: 2
# N° valores distintos en pp_total_raw: 11

# %% [markdown]
#  A excepción de district_id, los atributos son tipo categóricos.

# %%
products.head()
# Out:
#    LP ID                           URL  Product Name  Provider/Company Name  \
# 0  13117    https://www.splashmath.com   SplashLearn          StudyPad Inc.
# 1  66933          https://abcmouse.com  ABCmouse.com  Age of Learning, Inc
# 2  50479         https://www.abcya.com        ABCya!         ABCya.com, LLC
# 3  92993         http://www.aleks.com/         ALEKS    McGraw-Hill PreK-12
# 4  73104  https://www.achieve3000.com/   Achieve3000            Achieve3000
#
#             Sector(s) Category  \
# 0             PreK-12      LC
# 1             PreK-12      LC
# 2             PreK-12      LC
# 3  PreK-12; Higher Ed      LC
# 4             PreK-12      LC
#
#                                          Subcategory
# 0                         Digital Learning Platforms
# 1                         Digital Learning Platforms
# 2   Sites, Resources & Reference - Games & Simula...
# 3                         Digital Learning Platforms
# 4                         Digital Learning Platforms

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   LP ID                  372 non-null    int64
#  1   URL                    372 non-null    object
#  2   Product Name           372 non-null    object
#  3   Provider/Company Name  371 non-null    object
#  4   Sector(s)              352 non-null    object
#  5   Category               352 non-null    object
#  6   Subcategory            352 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 20.5+ KB

# %%
products.describe(include = 'all')
# Out:
#                LP ID                             URL      Product Name  \
# count     372.000000                             372               372
# unique           NaN                             372               372
# top              NaN  http://www.truenorthlogic.com/  True North Logic
# freq             NaN                               1                 1
# mean    54565.795699                             NaN               NaN
# std     26247.551437                             NaN               NaN
# min     10533.000000                             NaN               NaN
# 25%     30451.000000                             NaN               NaN
# 50%     53942.500000                             NaN               NaN
# 75%     77497.000000                             NaN               NaN
# max     99916.000000                             NaN               NaN
#
#        Provider/Company Name Sector(s) Category                  Subcategory
# ...

# %%
for col in products.columns:
  print(f'N° de valores distintos en {col}: {products[col].nunique()}')
# Out:
# N° de valores distintos en LP ID: 372
# N° de valores distintos en URL: 372
# N° de valores distintos en Product Name: 372
# N° de valores distintos en Provider/Company Name: 290
# N° de valores distintos en Sector(s): 5
# N° de valores distintos en Category: 4
# N° de valores distintos en Subcategory: 34

# %% [markdown]
# Las variables LP, URL y Product Name funcionan como identificadores de la muestra. La variable Provider/Company Name es muy específica. Las variables Sector(s), Category y Subcategory son atributos categóricos.

# %%
engagement_data.head()
# Out:
#          time    lp_id  pct_access  engagement_index    id
# 0  2020-01-01  16401.0        0.00               NaN  1142
# 1  2020-01-01  99916.0        0.37             11.24  1142
# 2  2020-01-01  26488.0        0.00               NaN  1142
# 3  2020-01-01  29322.0        0.00               NaN  1142
# 4  2020-01-01  69827.0        0.37             18.73  1142

# %%
engagement_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3024515 entries, 0 to 3024514
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   time              object
#  1   lp_id             float64
#  2   pct_access        float64
#  3   engagement_index  float64
#  4   id                int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 115.4+ MB

# %%
engagement_data.isnull().sum()
# Out:
# time                     0
# lp_id                   52
# pct_access            8353
# engagement_index    828653
# id                       0
# dtype: int64

# %% [markdown]
#  Las variables lp_id y pct_access contienen datos nulos.

# %%
engagement_data.describe(include='all')
# Out:
#               time         lp_id    pct_access  engagement_index            id
# count      3024515  3.024463e+06  3.016162e+06      2.195862e+06  3.024515e+06
# unique         366           NaN           NaN               NaN           NaN
# top     2020-12-10           NaN           NaN               NaN           NaN
# freq         14805           NaN           NaN               NaN           NaN
# mean           NaN  5.479196e+04  8.121765e-01      2.750297e+02  2.636342e+03
# std            NaN  2.648965e+04  4.076213e+00      2.075686e+03  2.163151e+03
# min            NaN  1.000300e+04  0.000000e+00      5.000000e-02  1.000000e+03
# 25%            NaN  3.085100e+04  0.000000e+00      8.700000e-01  1.270000e+03
# 50%            NaN  5.503100e+04  4.000000e-02      4.540000e+00  1.624000e+03
# 75%            NaN  7.753600e+04  2.000000e-01      3.180000e+01  3.558000e+03
# max            NaN  9.999100e+04  1.000000e+02      1.427434e+05  9.536000e+03

# %%
for col in engagement_data.columns:
  print(f'Número de valores distintos en {col}: {engagement_data[col].nunique()}')
# Out:
# Número de valores distintos en time: 366
# Número de valores distintos en lp_id: 7357
# Número de valores distintos en pct_access: 7248
# Número de valores distintos en engagement_index: 151418
# Número de valores distintos en id: 63

# %%
#Extraído de https://www.kaggle.com/code/assurivyshnavi/digital-learning
merged = engagement_data.copy()
merged['id'] = merged['id'].astype('int64')
merged = merged.merge(districts, left_on='id', right_on='district_id', how='left')

# %%
merged = merged.merge(products, left_on='lp_id', right_on='LP ID', how='left')

# %%
merged = merged.drop('district_id', axis=1)

# %%
merged = merged.drop('LP ID', axis=1)

# %%
merged['time'] = pd.to_datetime(merged['time'])

# %%
merged.head()
# Out:
#         time    lp_id  pct_access  engagement_index    id        state locale  \
# 0 2020-01-01  16401.0        0.00               NaN  1142  Connecticut  Rural
# 1 2020-01-01  99916.0        0.37             11.24  1142  Connecticut  Rural
# 2 2020-01-01  26488.0        0.00               NaN  1142  Connecticut  Rural
# 3 2020-01-01  29322.0        0.00               NaN  1142  Connecticut  Rural
# 4 2020-01-01  69827.0        0.37             18.73  1142  Connecticut  Rural
#
#   pct_black/hispanic pct_free/reduced county_connections_ratio pp_total_raw  \
# 0             0%-20%          20%-40%                 18%-100%          NaN
# 1             0%-20%          20%-40%                 18%-100%          NaN
# 2             0%-20%          20%-40%                 18%-100%          NaN
# 3             0%-20%          20%-40%                 18%-100%          NaN
# 4             0%-20%          20%-40%                 18%-100%          NaN
#
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3024515 entries, 0 to 3024514
# Data columns (total 17 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   time                      datetime64[ns]
#  1   lp_id                     float64
#  2   pct_access                float64
#  3   engagement_index          float64
#  4   id                        int64
#  5   state                     object
#  6   locale                    object
#  7   pct_black/hispanic        object
#  8   pct_free/reduced          object
#  9   county_connections_ratio  object
#  10  pp_total_raw              object
#  11  URL                       object
#  12  Product Name              object
#  13  Provider/Company Name     object
#  14  Sector(s)                 object
#  15  Category                  object
#  16  Subcategory               object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(12)
# memory usage: 392.3+ MB

# %%
print(merged.isna().sum())
# Out:
# time                              0
# lp_id                            52
# pct_access                     8353
# engagement_index             828653
# id                                0
# state                        660789
# locale                       660789
# pct_black/hispanic           660789
# pct_free/reduced             717603
# county_connections_ratio     936536
# pp_total_raw                1337693
# URL                         1238137
# Product Name                1238137
# Provider/Company Name       1238137
# Sector(s)                   1308434
# Category                    1308434
# Subcategory                 1308434
# dtype: int64

# %%
#Visualización de los datos
districts.head(1)
# Out:
#    district_id     state  locale pct_black/hispanic pct_free/reduced  \
# 0         8815  Illinois  Suburb             0%-20%           0%-20%
#
#   county_connections_ratio pp_total_raw
# 0                 18%-100%  14000-16000

# %% [markdown]
# 1.   **district_id:** El identificador único del distrito escolar
# 2.   **State:** El estado donde se ubica el distrito
# 3.   **locale:** Clasificación de la NCES que categoriza el territorio de los Estados Unidos en cuatro tipos: Ciudad, Suburbio, Pueblo y Rural.
# 4. **pct_black/hispanic:** Porcentaje de estudiantes en los distritos identificados como Negros o Hispanicos. Basado en los datos de la NCES durante 2018-2019
# 5. **pct_free/reduced** Porcentaje de estudiantes en los distritos que son candidatos para una beca alimenticia (especifícamente, para el almuerzo) parcial o total. Basado en los datos de la NCES durante 2018-2019
# 6. **county_connections_ratio:** ratio (Conexiones de alta velocidad residencial fija sobre los 200 kilobits por segundo en al menos una dirección/hogar).
# 7. **pp_total_raw:** gasto por pupilo (suma del gasto local y federal) de Edunomics Lab's National Education Resource Database on Schools project. La información del gasto es por cada escuela. Se usa el valor medio para representar el gasto para un distrito dado

# %%
fig, ax  = plt.subplots(figsize=(16, 8))
fig.suptitle('Distrubución de Estados', size = 20)
districts['state'].value_counts().head(15).plot(kind = 'pie', autopct='%1.1f%%', figsize=(16, 8), startangle=0).legend();

# %% [markdown]
#  Se observa que la mayor cantidad de personas estudiadas viven en Connecticut, Utah, Massachusetts e Illinois.

# %%
fig, ax  = plt.subplots(figsize=(16, 8))
fig.suptitle('Distribución de Localidades', size = 20)
districts['locale'].value_counts().head(15).plot(kind = 'pie', autopct='%1.1f%%', figsize=(16, 8), startangle=0).legend();
plt.show()

# %% [markdown]
#  Vemos que la mayoría de de personas vive en suburbios o zonas rurales, respresentando un 59.1% y 18.8% de la población respectivamente. Este hecho sugiere que la mayoría de las personas participantes en el estudio podrían enfrentar limitaciones en el acceso a recursos educativos, como el internet.

# %%
figure, axes = plt.subplots(figsize=(12, 5))

index = districts['pct_black/hispanic'].value_counts().index

graph = sns.countplot(
    data=districts,
    x= 'pct_black/hispanic',
    order=index,
    ax=axes
)

total = len(districts['pct_black/hispanic'])
total_nulos = len(districts['pct_black/hispanic'][districts['pct_black/hispanic'].isnull()])
for p in graph.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    x = p.get_x() + p.get_width() / 2 - 0.1
    y = p.get_height()
    graph.annotate(percentage, (x, y), ha='center', va='bottom')

axes.set_title('Black/hispanic')
plt.show()

print(f'Porcentaje de datos nulos: {(100*total_nulos/total)}%' )
# Out:
# Porcentaje de datos nulos: 24.463519313304722%

# %% [markdown]
# **pct_black/hispanic:** Porcentaje de estudiantes en los distritos identificados como Negros o Hispanicos. Basado en los datos de la NCES durante 2018-2019
#
#
#  Vemos que la mitad de los distritos posee una identificación con negro/hispano de entre un 0 a 20%, mientras que solo un 4.5% de los distritos posee una identificación de entre 80% a 100%. También, que a medida que aumenta el porcentaje de identificación, más bajo es el porcentaje de la población representada.

# %%
figure, axes = plt.subplots(figsize=(12, 5))

index = districts['pct_free/reduced'].value_counts().index

graph = sns.countplot(
    data=districts,
    x= 'pct_free/reduced',
    order=index,
    ax=axes
)

total = len(districts['pct_free/reduced'])
total_nulos = len(districts['pct_free/reduced'][districts['pct_free/reduced'].isnull() == True])
for p in graph.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    x = p.get_x() + p.get_width() / 2 - 0.1
    y = p.get_height()
    graph.annotate(percentage, (x, y), ha='center', va='bottom')

axes.set_title('Free/Reduced')
plt.show()

print(f'Porcentaje de datos nulos: {100*total_nulos/total}%' )
# Out:
# Porcentaje de datos nulos: 36.48068669527897%

# %% [markdown]
# **pct_free/reduced:** Porcentaje de estudiantes en los distritos que son candidatos para una beca alimenticia (especifícamente, para el almuerzo) parcial o total. Basado en los datos de la NCES durante 2018-2019
#
#
#  Vemos que la mayoría de los distritos, entre un 0-40% de sus estudiantes son candidatos a una beca. Por otro lado, el 7.3% de los distritos, entre el 60-100% de sus estudiantes son candidatos a una beca.

# %%
figure, axes = plt.subplots(figsize=(12, 5))

index = districts['county_connections_ratio'].value_counts().index

graph = sns.countplot(
    data=districts,
    x= 'county_connections_ratio',
    order=index,
    ax=axes
)

total = len(districts['county_connections_ratio'])
total_nulos = len(districts['county_connections_ratio'][districts['county_connections_ratio'].isnull() == True])
for p in graph.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    x = p.get_x() + p.get_width() / 2 - 0.1
    y = p.get_height()
    graph.annotate(percentage, (x, y), ha='center', va='bottom')

axes.set_title('County connections ratio')
plt.show()

print(f'Porcentaje de datos nulos: {100*total_nulos/total}%' )
# Out:
# Porcentaje de datos nulos: 30.472103004291846%

# %% [markdown]
# **County_connections_ratio:** ratio (Conexiones de alta velocidad residencial fija sobre los 200 kilobits por segundo en al menos una dirección/hogar).

# %%
figure, axes = plt.subplots(figsize=(15, 5))

index = districts['pp_total_raw'].value_counts().index

graph = sns.countplot(
    data=districts,
    x= 'pp_total_raw',
    order=index,
    ax=axes
)

total = len(districts['pp_total_raw'])
total_nulos = len(districts['pp_total_raw'][districts['pp_total_raw'].isnull() == True])
for p in graph.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height() / total)
    x = p.get_x() + p.get_width() / 2 - 0.1
    y = p.get_height()
    graph.annotate(percentage, (x, y), ha='center', va='bottom')

axes.set_title('pp_total_raw')
plt.show()

print(f'Porcentaje de datos nulos: {100*total_nulos/total}%' )
# Out:
# Porcentaje de datos nulos: 49.35622317596567%

# %% [markdown]
# **pp_total_raw:** gasto por pupilo (suma del gasto local y federal) de Edunomics Lab's National Education Resource Database on Schools project. La información del gasto es por cada escuela. Se usa el valor medio para representar el gasto para un distrito dado.
#
#
#  La mitad de los datos corresponden a datos nulos, lo cual resta veracidad a la observación. Vemos que la mayoría de los distritos gasta entre 8000-12000. Luego, se observa que a medida que aumenta el gasto por pupilo, menor es el porcentaje.

# %%
#visualización productos
products.head(1)
# Out:
#    LP ID                         URL Product Name Provider/Company Name  \
# 0  13117  https://www.splashmath.com  SplashLearn         StudyPad Inc.
#
#   Sector(s) Category                  Subcategory
# 0   PreK-12      LC    Digital Learning Platforms

# %% [markdown]
# 1.   **LP ID:** El identificador único del producto
# 2.   **URL:** Link web hacia el producto en específico
# 3.   **Provider/Company Name:** Nombre del proveedor del producto
# 4. **Sector(s):** Sector de la eduación donde es usado el producto
# 5. **Primary Essential Function:** La función básica del producto. Hay dos niveles de etiquetas acá:\
# **Category:** Los productos se pueden etiquetar como uno de estos tres:\
# -LC = Aprendizaje y Curriculum\
# -CM = Manejo de la sala de clases\
# -SDO = Operaciones de escuela y distrito\
# **Subcategory:** Una función más especifica del producto

# %%
index = products['Provider/Company Name'].value_counts().head(20).index
ax = sns.countplot(data= products, y = 'Provider/Company Name', order = index, )

total = len(products[['Provider/Company Name']])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_width()/total)
    x = p.get_x() + p.get_width() + 0.1
    y = p.get_y() + p.get_height() / 2
    ax.annotate(percentage, (x, y), ha='left', va='center')

plt.title('Los 20 proveedores con más productos disponibles')
plt.show()

# %% [markdown]
#  Se observa que el principal proveedor es Google LLC, sobrepasando con diferencia al segundo lugar, Houghton Mifflin Harcourt.

# %%
plt.figure(figsize = (15,5))
index = products['Sector(s)'].value_counts().index
ax = sns.countplot(
      data= products,
      x = 'Sector(s)',
      order = index,
      )


total = len(products['Sector(s)'])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.1
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='bottom')

plt.title('Cantitad por sectores')
plt.show()

# %% [markdown]
# Sector(s): Sector de la eduación donde es usado el producto.
#
#  Vemos que la mayoría de los productos están destinados al estudiantado y, en particular, que el sector que más utiliza las herramientas propuestas es Prekinder junto con educación superior.

# %%
index = products['Category'].value_counts().head(20).index
ax = sns.countplot(data= products, y = 'Category', order = index, )

total = len(products[['Category']])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_width()/total)
    x = p.get_x() + p.get_width() + 0.1
    y = p.get_y() + p.get_height() / 2
    ax.annotate(percentage, (x, y), ha='left', va='center')

plt.title('Conteo Category')
plt.show()

# %% [markdown]
# Los productos se pueden etiquetar como uno de estos tres:\
# -LC = Aprendizaje y Curriculum
# -CM = Manejo de la sala de clases
# -SDO = Operaciones de escuela y distrito
#
#  La categoría más popular es LC, sobrepasando con un 64% el segundo lugar, CM.

# %%
index = products['Subcategory'].value_counts().head(20).index
ax = sns.countplot(data= products, y = 'Subcategory', order = index, )

total = len(products[['Subcategory']])
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_width()/total)
    x = p.get_x() + p.get_width() + 0.1
    y = p.get_y() + p.get_height() / 2
    ax.annotate(percentage, (x, y), ha='left', va='center')

plt.title('Conteo Subcategory')
plt.show()

# %% [markdown]
#  Las tres subcategorías más populares entre los productos son Digital Learning Platforms, Sites, Resources & Reference y Content Creation & Curation.

# %%
#Visualización Merged
merged.head(1)
# Out:
#         time    lp_id  pct_access  engagement_index    id        state locale  \
# 0 2020-01-01  16401.0         0.0               NaN  1142  Connecticut  Rural
#
#   pct_black/hispanic pct_free/reduced county_connections_ratio pp_total_raw  \
# 0             0%-20%          20%-40%                 18%-100%          NaN
#
#                     URL Product Name Provider/Company Name  \
# 0  https://www.pbs.org/          PBS                   PBS
#
#                        Sector(s) Category                    Subcategory
# 0  PreK-12; Higher Ed; Corporate      LC    Sites, Resources & Reference

# %%
import matplotlib.dates as mdates
from matplotlib import ticker

# ========================
# 1) Preparar los datos
# ========================
# Asegurar que 'time' es datetime
merged['time'] = pd.to_datetime(merged['time'])

# Construir temp igual que el código original
temp = pd.DataFrame(merged.groupby(['time', 'id'])['time'].count())
temp = temp.rename(columns={"time": "amount"})
temp = temp.reset_index(drop=False)
temp = temp.groupby('time')['amount'].mean()

# Índice de fechas
dates = pd.to_datetime(temp.index)
y = temp.values
ymax = y.max()

# Convertir fechas a números (días) para matplotlib
x = mdates.date2num(dates)

# Rango de verano en números
summer_dates = pd.date_range("2020-06-01", "2020-08-23", freq="D")
summer = mdates.date2num(summer_dates)

# Fechas importantes en números
cierre_escuelas = mdates.date2num(np.datetime64("2020-02-12"))
covid_pandemia = mdates.date2num(np.datetime64("2020-03-11"))
vacaciones_dia = mdates.date2num(np.datetime64("2020-06-27"))

# ========================
# 2) Gráfico
# ========================
background_color = "#B4DBE9"

plt.rcParams['figure.dpi'] = 300
fig = plt.figure(figsize=(9, 2), facecolor=background_color)   # un poco más alto
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0, hspace=0)
ax0 = fig.add_subplot(gs[0, 0])
ax0.set_facecolor(background_color)

# --- barras ---
ax0.bar(
    x, y,
    width=1.0,
    color='white',        # barras blancas
    edgecolor='dimgray',  # bordes grises
    linewidth=0.5,
    zorder=2
)

# --- franja amarilla de vacaciones de verano ---
ax0.fill_between(
    summer,
    0,
    ymax,
    color='#ffd514',
    alpha=0.5,
    zorder=1,
    linewidth=0
)

# --- líneas verticales ---
ax0.axvline(cierre_escuelas, color='#ffd514', alpha=0.7)
ax0.axvline(covid_pandemia, color='#ffd514', alpha=0.7)

for s in ["right", "top"]:
    ax0.spines[s].set_visible(False)
ax0.grid(which='major', axis='x', zorder=0, color='#EEEEEE', lw=0.3)
ax0.grid(which='major', axis='y', zorder=0, color='#EEEEEE', lw=0.3)

# limitar el eje X de enero a diciembre 2020
ax0.set_xlim(
    mdates.date2num(np.datetime64("2020-01-01")),
    mdates.date2num(np.datetime64("2020-12-31"))
)

# === títulos dentro del área ===
x0, x1 = ax0.get_xlim()
y0, y1 = ax0.get_ylim()

ax0.text(
    x0, y1*0.97,
    'Promedio diario de productos accedidos',
    color='black', fontsize=7,
    ha='left', va='top', weight='bold'
)
ax0.text(
    x0, y1*0.90,
    'Después de las vacaciones de verano, hay un aumento en los productos accedidos',
    color='#292929', fontsize=5,
    ha='left', va='top'
)

ax0.annotate(
    "Cierre temporal de escuelas.",
    xy=(cierre_escuelas, ymax*0.8),
    xytext=(mdates.date2num(np.datetime64("2020-01-10")), ymax*0.65),
    arrowprops=dict(arrowstyle="->"),
    fontsize=5
)
ax0.annotate(
    "COVID-19\nPandemia",
    xy=(covid_pandemia, ymax*0.8),
    xytext=(mdates.date2num(np.datetime64("2020-03-20")), ymax*0.6),
    arrowprops=dict(arrowstyle="->"),
    fontsize=5
)
ax0.annotate(
    "Vacaciones de verano",
    xy=(vacaciones_dia, ymax*0.4),
    xytext=(vacaciones_dia, ymax*0.4),
    fontsize=5
)

# === ejes ===
ax0.set_xlabel("fecha", fontsize=6, weight='bold')
ax0.set_ylabel("productos", fontsize=6, weight='bold')

ax0.tick_params('both', length=2, which='major', labelsize=5)
ax0.xaxis.set_major_locator(mdates.MonthLocator())
ax0.xaxis.set_major_formatter(mdates.DateFormatter('%b 2020'))  # Jan 2020, Feb 2020, ...

y_format = ticker.FuncFormatter(lambda x, p: format(int(x), ','))
ax0.yaxis.set_major_formatter(y_format)

plt.tight_layout()
plt.show()

# %% [markdown]
# El promedio diario de productos accedidos está alrededor de 300-500 por distrito escolar en 2020.
#
# Cada mes presenta fluctuaciones, que sigue un patrón de 5-2, es decir, 5 días de escuela y 2 días de fin de semana. Aunque el número de productos accedidos disminuye durante el fin de semana, aún observamos productos accedidos en esos días, siendo aproximadamente un 25%-50% en comparación con los días de la semana. Esto tiene sentido, ya que los fines de semana no son días de clases.
#
# A mediados de febrero, en el cierre temporal de escuelas por la pandemia, vemos un aumento en los productos accedidos, aunque el aumento es marginal. Luego, observamos una baja durante las vacaciones de verano y, después, un aumento en el promedio diario de productos accedidos.

# %% [markdown]
# ## II.- Titanic - Machine Learning from Disaster
#
# <img src="https://i.pinimg.com/originals/8c/ef/e7/8cefe799c4d5d2ad4ad7f6524d3838f4.png" width = "400" align="center"/>

# %% [markdown]
# El desafío **Titanic - Machine Learning from Disaster** en [Kaggle](https://www.kaggle.com/competitions/titanic/overview/description) invita a predecir qué pasajeros sobrevivieron al naufragio del Titanic mediante un modelo de machine learning. Utiliza datos reales de los pasajeros, como su nombre, edad, género y clase socioeconómica, para explorar patrones de supervivencia y construir un modelo predictivo. Este es uno de los desafíos más populares de Kaggle y un excelente punto de partida para aprender sobre machine learning y análisis de datos.
#
# ### Pasos para participar:
#
# 1. **Unirse a la competencia**:
#    - [Crea una cuenta o inicia sesión en Kaggle](https://www.kaggle.com/account/login?returnUrl=%2Fc%2Ftitanic) y acepta las reglas para acceder a los datos de la competencia.
#
# 2. **Descargar y explorar los datos**:
#    - Descarga los archivos `train.csv` y `test.csv` desde la [página de datos](https://www.kaggle.com/competitions/titanic/data).
#    - `train.csv` contiene información de 891 pasajeros, incluyendo si sobrevivieron o no (columna `Survived`). En `test.csv`, se oculta esta columna para que tu modelo prediga la supervivencia de 418 pasajeros adicionales.
#
# 3. **Desarrollar el modelo**:
#    - Usa `train.csv` para explorar y descubrir patrones, luego entrena un modelo de machine learning que pueda predecir la supervivencia en `test.csv`. Un recurso útil para aprender es el [tutorial de Alexis Cook](https://www.kaggle.com/alexisbcook/titanic-tutorial), que explica paso a paso cómo hacer tu primera predicción.
#    - Puedes explorar notebooks de otros participantes para inspiración y técnicas avanzadas en la [sección de notebooks](https://www.kaggle.com/c/titanic/notebooks).
#
# 4. **Realizar una predicción y enviar tu archivo**:
#    - El archivo CSV de predicciones debe tener dos columnas: `PassengerId` y `Survived`. Puedes consultar un ejemplo en el archivo `gender_submission.csv` disponible en la [página de datos](https://www.kaggle.com/competitions/titanic/data).
#    - Sube tu archivo en la sección de envíos y revisa tu puntaje de precisión, que mide el porcentaje de pasajeros que tu modelo predijo correctamente.
#
# 5. **Revisar el leaderboard y mejorar el modelo**:
#    - Ve tu posición en el [leaderboard](https://www.kaggle.com/c/titanic/leaderboard) y mejora tu modelo basándote en ideas de los foros o pruebas adicionales.
#
# ### Ayuda y recursos adicionales:
#
# - [Foro de discusión del Titanic](https://www.kaggle.com/c/titanic/discussion): Un espacio donde puedes hacer preguntas y ver consejos de otros participantes.
# - [Vídeo sobre la jerga de Kaggle](https://www.youtube.com/watch?v=sEJHyuWKd-s) por Dr. Rachael Tatman, para entender mejor los términos comunes en Kaggle.
# - [Notebooks de la competencia](https://www.kaggle.com/c/titanic/notebooks): Revisa notebooks compartidos para ver cómo otros abordan el desafío.
#
# Este desafío es ideal para principiantes en machine learning y permite practicar desde la limpieza de datos hasta el desarrollo y evaluación de modelos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import os
import warnings
warnings.filterwarnings("ignore")

# %%
folder_path = '/content/drive/MyDrive/data_hw2/titanic/'
files = os.listdir(folder_path)

# %%
dataframes = {}  # Diccionario para almacenar los DataFrames

for file in files:
    if file.endswith('.csv'):
        file_path = os.path.join(folder_path, file)
        df_name = file.split('.')[0]  # Usa el nombre del archivo como clave del diccionario
        dataframes[df_name] = pd.read_csv(file_path)
dataframes.keys()
# Out:
# dict_keys(['train', 'test', 'gender_submission', 'submission'])

# %%
df_gender_sub = dataframes['gender_submission']
df_test = dataframes['test']
df_train = dataframes['train']

# %% [markdown]
# ### EDA

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# El dataframe contiene 891 datos y 12 columnas, el target (`'Survived'`) y los atributos, tipo numéricos y categóricos.
#
# Todos los datos están etiquetados, es decir, la columna `'Survived'` (target) no presenta datos nulos.
#
# Algunas columnas poseen datos nulos. Estas son:
# - **Age** (numérica): 714 datos no nulos.
# - **Cabin** (categórica): 204 datos no nulos.
# - **Embarked** (categórica): 889 datos no nulos.
#
# Dado que la columna `'Cabin'` posee más datos nulos que no nulos, eliminaremos esta columna para no perturbar tanto la muestra.
#
# Para la variable 'Age', reemplazaremos los datos nulos con la desviación estándar.
#
# Para la variable 'Embarked', reemplazaremos con la moda.

# %%
df_train2 = df_train.copy()

df_train2 = df_train2.drop('Cabin', axis=1)

std_age = df_train2['Age'].std()
df_train2['Age'] = df_train2['Age'].fillna(std_age)

moda_embarked = df_train2['Embarked'].mode().iloc[0]
df_train2['Embarked'] = df_train2['Embarked'].fillna(moda_embarked)

# %%
df_train2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df_train2['PassengerId'].nunique()
# Out:
# 891

# %% [markdown]
# La columna `'PassengerId'` identifica cada dato del dataframe. Además, importante, no existen 2 o más reportes de un mismo pasajero.

# %%
# Establecer la columna 'PassengerId' como índice del dataframe:
df_train2 = df_train2.set_index('PassengerId')
df_train2
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
# Target / Features:
y_train = df_train2['Survived']#.values
X_train = df_train2.drop('Survived', axis=1)#.values

# %%
y_train.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# Los datos están ligeramente desbalanceados, pero la situación no es grave.

# %%
# Dataframe con variables numéricas:
df_num = X_train.select_dtypes(include='number')
df_num.head()
# Out:
#              Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                 3  22.0      1      0   7.2500
# 2                 1  38.0      1      0  71.2833
# 3                 3  26.0      0      0   7.9250
# 4                 1  35.0      1      0  53.1000
# 5                 3  35.0      0      0   8.0500

# %%
# Dataframe con variables categóricas:
df_categ = X_train.select_dtypes(include=['object'])
df_categ.head()
# Out:
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
#
#                        Ticket Embarked
# PassengerId
# 1                   A/5 21171        S
# 2                    PC 17599        C
# 3            STON/O2. 3101282        S
# 4                      113803        S
# 5                      373450        S

# %%
# Dispersión de los atributos numéricos por clase:
for col in df_num.columns.values:
    fig, ax = plt.subplots(figsize=(8, 4), ncols=2)

    # Gráfico para 'Survived' == 0
    sns.histplot(x=df_train2[col][df_train2['Survived'] == 0], kde=True, bins=10, ax=ax[0])
    ax[0].set_title(f'Distribución para {col}, Survived=0')

    # Gráfico para 'Survived' == 1
    sns.histplot(x=df_train2[col][df_train2['Survived'] == 1], kde=True, bins=10, ax=ax[1])
    ax[1].set_title(f'Distribución para {col}, Survived=1')

    plt.show()

# %% [markdown]
# Se observa una leve diferencia en la distribución de los datos de los atributos numéricos. Sin embargo, no permite discriminar de manera clara la relevancia de las variables sobre la supervivencia de los pasajeros.

# %%
df_categ.nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Embarked      3
# dtype: int64

# %%
df_categ = df_categ.drop(['Name', 'Ticket'], axis=1)

# %%
# Dispersión de los atributos categóricos por clase:
for col in df_categ.columns.values:
    fig = plt.figure(figsize=(4, 4))

    sns.countplot(x=df_train2[col], hue=df_train2['Survived'])
    ax[0].set_title(f'Distribución para {col}')

    plt.show()

# %% [markdown]
# Se observa la relevancia del sexo en la supervivencia del pasajero y, por el contrario, la poca relevancia de la variable `'Embarked'`, ya que ambas clases se distribuyen de la misma forma.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_num_scaled = scaler.fit_transform(df_num)
df_num_scaled = pd.DataFrame(df_num_scaled, columns=df_num.columns, index = X_train.index)
print('Datos numéricos estandarizados:')
display(df_num_scaled.head())
# Out:
# Datos numéricos estandarizados:
#              Pclass       Age  SibSp  Parch      Fare
# PassengerId
# 1               1.0  0.271174  0.125    0.0  0.014151
# 2               0.0  0.472229  0.125    0.0  0.139136
# 3               1.0  0.321438  0.000    0.0  0.015469
# 4               0.0  0.434531  0.125    0.0  0.103644
# 5               1.0  0.434531  0.000    0.0  0.015713

# %%
from sklearn.feature_selection import f_classif

scores = []
for col in df_num.columns.values:
  x = df_num_scaled[col].values.reshape(-1, 1)
  score = f_classif(x, y_train)[0][0]
  scores.append(score)

# %%
fig, axes = plt.subplots(figsize=(6,4), nrows=1, ncols=1)
plot_data = pd.DataFrame({'atributos_num': df_num.columns.values, 'fisher_score': scores})
plot_data = plot_data.sort_values(by='fisher_score', ascending=False)
p = sns.barplot(data=plot_data, x='fisher_score', y='atributos_num', palette="Blues_d",ax=axes)
plt.show()

# %% [markdown]
# Los atributos numéricos más relevantes son 'Pclass' y 'Fare', basandonos en la puntuación fisher-score entre cada una de estas con el target.

# %%
from sklearn.feature_selection import mutual_info_classif as mi
from sklearn.preprocessing import LabelEncoder

scores = []
for col in df_categ.columns.values:
  x = LabelEncoder().fit_transform(df_train2[col]).reshape(-1,1)
  score = mi(x, y_train, discrete_features=True)[0]
  scores.append(score)

# %%
fig, axes = plt.subplots(figsize=(4,4), nrows=1, ncols=1)
plot_data = pd.DataFrame({'x': df_categ.columns.values, 'y': scores})
plot_data = plot_data.sort_values(by='y', ascending=False)
p = sns.barplot(data=plot_data,x='y', y='x', palette="Blues_d",ax=axes)
plt.show()

# %% [markdown]
#  Tal como se intuía a partir de la visualización, el atributo 'Sex' es muy relevante para la predicción, a diferencia de 'Embarked'. Esto, en base a la información mutua entre cada atributo con el target.
#
#  La desventaja de recortar variables en base a la puntuación fisher-score y de la información mutua es que se tratan de métodos de filtrado individual, es decir, no tienen la capacidad de detectar redundancias ni complementariedades entre atributos.

# %%
df_num_procesado = df_num_scaled[['Pclass', 'Fare']]
df_num_procesado.head()
# Out:
#              Pclass      Fare
# PassengerId
# 1               1.0  0.014151
# 2               0.0  0.139136
# 3               1.0  0.015469
# 4               0.0  0.103644
# 5               1.0  0.015713

# %%
df_categ_procesado = pd.get_dummies(df_categ['Sex'])
df_categ_procesado.head()
# Out:
#              female   male
# PassengerId
# 1             False   True
# 2              True  False
# 3              True  False
# 4              True  False
# 5             False   True

# %% [markdown]
# En lo que sigue, trabajaremos 2 alternativas.

# %% [markdown]
# **Celda 1:**

# %%
'''
X_train_procesado = pd.concat([df_num_procesado, df_categ_procesado], axis=1)
X_train_procesado.head()
'''
# Out:
# '\nX_train_procesado = pd.concat([df_num_procesado, df_categ_procesado], axis=1)\nX_train_procesado.head()\n'

# %% [markdown]
# **Celda 2:**

# %%
X_train_procesado = pd.concat([df_num_scaled, df_categ_procesado], axis=1)
X_train_procesado.head()
# Out:
#              Pclass       Age  SibSp  Parch      Fare  female   male
# PassengerId
# 1               1.0  0.271174  0.125    0.0  0.014151   False   True
# 2               0.0  0.472229  0.125    0.0  0.139136    True  False
# 3               1.0  0.321438  0.000    0.0  0.015469    True  False
# 4               0.0  0.434531  0.125    0.0  0.103644    True  False
# 5               1.0  0.434531  0.000    0.0  0.015713   False   True

# %% [markdown]
# ### Entrenamiento

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Instanciar modelos:
lr = LogisticRegression()
svc = SVC()
rfc = RandomForestClassifier()

# %% [markdown]
# ### Grid Search: Logistic Regressor

# %%
# Parámetros:
param_grid_lr = {'penalty' : ['l1', 'l2'],
                 'C': [0.001, 0.01, 0.1, 1, 10, 100],
                 'class_weight' : ['balanced', None]
                 }
param_grid_lr

# Aplicar greed search:
gs_lr = GridSearchCV(estimator = lr,
                  param_grid = param_grid_lr,
                  scoring = 'accuracy',
                  cv = 5,
                  n_jobs = -1)

gs_lr = gs_lr.fit(X_train_procesado, y_train)

# Imprimir resultados:
print(gs_lr.best_score_)
print(gs_lr.best_params_)
# Out:
# 0.7867365513778168
# {'C': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}

# %% [markdown]
# ### Grid Search: SVC

# %%
# Parámetros:
param_grid_svc = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto'],
    'class_weight' : ['balanced', None]
}

# Aplicar greed search:
gs_svc = GridSearchCV(estimator = svc,
                  param_grid = param_grid_svc,
                  scoring = 'accuracy',
                  cv = 5,
                  n_jobs = -1)

gs_svc = gs_svc.fit(X_train_procesado, y_train)

# Imprimir resultados:
print(gs_svc.best_score_)
print(gs_svc.best_params_)
# Out:
# 0.8293892411022534
# {'C': 10, 'class_weight': None, 'gamma': 'scale', 'kernel': 'poly'}

# %% [markdown]
# ### Grid Search: Random Forest Classifier

# %%
# Parámetros:
param_grid_rfc = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'class_weight' : ['balanced', None]
}

# Aplicar greed search:
gs_rfc = GridSearchCV(estimator = rfc,
                  param_grid = param_grid_rfc,
                  scoring = 'accuracy',
                  cv = 5,
                  n_jobs = -1)

gs_rfc = gs_rfc.fit(X_train_procesado, y_train)

# Imprimir resultados:
print(gs_rfc.best_score_)
print(gs_rfc.best_params_)
# Out:
# 0.8384093904965162
# {'class_weight': None, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}

# %% [markdown]
#  El modelo con mejor desempeño obtenido es Random Forest Classifier dado por el grid search.

# %% [markdown]
# ### Procesamiento Datos de Prueba

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test2 = df_test.copy()

# %%
df_test2 = df_test2.set_index('PassengerId')

# %%
# Dataframe con variables numéricas:
df_num_test= df_test2.select_dtypes(include='number')
df_num_test.head()
# Out:
#              Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 892               3  34.5      0      0   7.8292
# 893               3  47.0      1      0   7.0000
# 894               2  62.0      0      0   9.6875
# 895               3  27.0      0      0   8.6625
# 896               3  22.0      1      1  12.2875

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_num_test_scaled = scaler.fit_transform(df_num_test)
df_num_test_procesado = pd.DataFrame(df_num_test_scaled, columns=df_num_test.columns, index = df_num_test.index)
print('Datos numéricos estandarizados:')
display(df_num_test_procesado.head())
# Out:
# Datos numéricos estandarizados:
#                Pclass       Age     SibSp     Parch      Fare
# PassengerId
# 892          0.873482  0.298549 -0.499470 -0.400248 -0.497811
# 893          0.873482  1.181328  0.616992 -0.400248 -0.512660
# 894         -0.315819  2.240662 -0.499470 -0.400248 -0.464532
# 895          0.873482 -0.231118 -0.499470 -0.400248 -0.482888
# 896          0.873482 -0.584229  0.616992  0.619896 -0.417971

# %%
# Reemplazar datos nulos por la media de cada columna
df_num_test_procesado = df_num_test_procesado.fillna(df_num_test_procesado.mean())

# %%
df_num_test_procesado.isnull().sum()
# Out:
# Pclass    0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# dtype: int64

# %%
df_sex_test = df_test2['Sex']
df_sex_test
# Out:
# PassengerId
# 892       male
# 893     female
# 894       male
# 895       male
# 896     female
#          ...
# 1305      male
# 1306    female
# 1307      male
# 1308      male
# 1309      male
# Name: Sex, Length: 418, dtype: object

# %%
df_sex_test.isnull().sum()
# Out:
# np.int64(0)

# %%
df_sex_procesado = pd.get_dummies(df_sex_test)
df_sex_procesado.head()
# Out:
#              female   male
# PassengerId
# 892           False   True
# 893            True  False
# 894           False   True
# 895           False   True
# 896            True  False

# %% [markdown]
# Si se ejecutó la celda 1 en la Eda, ejecute la siguiente celda:

# %%
'''
df_test_procesado = df_num_test_procesado[['Pclass', 'Fare']]
df_test_procesado.head()
'''
# Out:
# "\ndf_test_procesado = df_num_test_procesado[['Pclass', 'Fare']]\ndf_test_procesado.head()\n"

# %% [markdown]
# Si se ejecutó la celda 2 en la Eda, ejecute la siguiente celda:

# %%
df_test_procesado = df_num_test_procesado
X_test_procesado = pd.concat([df_test_procesado, df_sex_procesado], axis=1)
X_test_procesado.head()
# Out:
#                Pclass       Age     SibSp     Parch      Fare  female   male
# PassengerId
# 892          0.873482  0.298549 -0.499470 -0.400248 -0.497811   False   True
# 893          0.873482  1.181328  0.616992 -0.400248 -0.512660    True  False
# 894         -0.315819  2.240662 -0.499470 -0.400248 -0.464532   False   True
# 895          0.873482 -0.231118 -0.499470 -0.400248 -0.482888   False   True
# 896          0.873482 -0.584229  0.616992  0.619896 -0.417971    True  False

# %% [markdown]
# **Predicción:**

# %%
mejor_modelo = gs_rfc.best_estimator_
mejor_modelo.fit(X_train_procesado, y_train)
y_pred = mejor_modelo.predict(X_test_procesado)

# %% [markdown]
# CSV Kaggle

# %%
# Ejemplo Kaggle:
df_gender_sub.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
data = pd.DataFrame(y_pred, index = X_test_procesado.index)
data.rename(columns = {0 : 'Survived'}, inplace = True)
data = data.reset_index()
data.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         1
# 4          896         0

# %%
csv_file_path = os.path.join(folder_path, 'submission.csv')
data.to_csv(csv_file_path, index=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La submission correspondiente al puntaje 0.63397 se obtuvo al ejecutar las celdas 1. Estas recortan las variables de bajo puntaje fisher-score.
#
# En cambio, la de 0.76794 se obtuvo al ejecutar las celdas 2, y consiste en mantener todas las variables numéricas.
